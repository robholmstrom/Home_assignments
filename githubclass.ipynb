# %%
import numpy as np #numpy provides fast mathematical funtion processing
import pandas as pd #pandas is used for easy Indexing and sata collection tools

# %%
# This is called your data from
# This number sign iis called a comment 
File = pd.read_csv('https://raw.githubusercontent.com/robholmstrom/githubclass/master/AYUSHHospitals.csv')
File.head() #This funcruob
# Out:
#   Srl no.         State / UT  ... Unnamed: 8 Unnamed: 9
# 0     NaN                NaN  ...     Others      Total
# 1      -1                 -2  ...         -9        -10
# 2       1     Andhra Pradesh  ...          0        365
# 3       2  Arunachal Pradesh  ...         25        125
# 4       3              Assam  ...          0        205
#
# [5 rows x 10 columns]
